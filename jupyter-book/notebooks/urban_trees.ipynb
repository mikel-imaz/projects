# %% [markdown]
# # Urban Trees

# %% [markdown]
# ![urban_trees.jpg](img/urban_trees.jpg)

# %% [markdown]
# Dec, 2022

# %% [markdown]
# In December 2022 signs were placed beside some trees in my town. They were metal plaques with the name of the corresponding tree species engraved on them, the botanical denomination plus the Basque and Spanish common names.
#
# When I saw the first sign, I thought that they were not going to last long. They would be vandalised and taken away sooner rather than later. The thought of it saddened me because I have always been fond of urban trees, and now that I had the opportunity of learning about some unknown identities, I was sure this information would vanish soon.
#
# So I took action and decided to register them myself. I made a couple of forays, during which I scoured the town to find the plaques. It was fun, sort of like playing a *Where's Wally* gymkhana. I wrote the names and the location in a file and made this mini-project. Now I do not worry anymore about the fate of these signs, because the data they contain is safe and sound in the cloud.

# %%
# Import packages
import pandas as pd
import folium

# Read the data
trees = pd.read_csv("data/zuhaitzak.csv")
trees
# Out:
#                        name                name_eu                  name_es  \
# 0   Liriodrendon tulipifera     Idio-bihotz arbola   Tulipífero de Virginia
# 1          Acer platanoides       Astigar zorrotza                Arce real
# 2          Betula pubescens           Urki iletsua        Abedul pubescente
# 3         Prunus cerasifera    Aranondo japoniarra          Ciruelo japonés
# 4       Magnolia liliiflora        Tulipa magnolia         Magnolia tulipán
# 5   Liquidambar styraciflua           Likidambarra              Liquidámbar
# 6      Magnolia grandiflora               Magnolia                 Magnolia
# 7              Ficus carica               Pikondoa                  Higuera
# 8       Cinnamomum camphora           Kanforrondoa              Alcanforero
# 9             Olea europaea              Olibondoa                    Olivo
# 10            Quercus robur       Haritz Kanduduna        Roble pedunculado
# 11            Juglans regia          Intxaurrondoa                    Nogal
# 12      Cercis siliquastrum        Amodio zuhaitza           Árbol del amor
# 13             Ulmus pumila      Siberiako zumarra           Olmo siberiano
# 14         Salix babylonica        Sahats negartia             Sauce llorón
# 15            Ginkgo biloba                 Ginkgo                   Gingko
# 16          Tilia tomentosa         Ezki zilarkara            Tilo plateado
# 17             Quercus ilex                  Artea                   Encina
# 18            Quercus robur       Haritz Kanduduna        Roble pedunculado
# 19     Platanus x hispanica        Platano arrunta        Plátano de sombra
# 20          Tilia tomentosa         Ezki zilarkara            Tilo plateado
# 21         Salix babylonica        Sahats negartia             Sauce llorón
# 22         Carpinus betulus   Xarma (Pago lizarra)                    Carpe
# 23         Prunus serrulata  Gereziondo japoniarra           Cerezo japonés
# 24       Tilia platyphyllos       Ezki hostozabala               Tilo común
# 25  Koelreuteria paniculata   Txinako xaboi arbola      Árbol de farolillos
# 26      Ligustrum japonicum     Arbustu japoniarra       Aligustre de japón
# 27         Corylus avellana               Hurritza                 Avellano
# 28         Sorbus aucuparia            Otsalizarra  Serbal de los cazadores
# 29          Ilex aquifolium               Korostia                    Acebo
# 30           Laurus nobilis                Erramua                   Laurel
# 31          Fagus sylvatica            Pago gorria                Haya roja
#
#           lat       lng
# 0   43.086719 -2.321678
# 1   43.086785 -2.321637
# 2   43.088292 -2.321790
# 3   43.088463 -2.321800
# 4   43.088353 -2.321855
# 5   43.088711 -2.320388
# 6   43.089846 -2.318472
# 7   43.090004 -2.316878
# 8   43.090498 -2.316668
# 9   43.090782 -2.316658
# 10  43.091001 -2.316331
# 11  43.092976 -2.314954
# 12  43.093494 -2.314714
# 13  43.093343 -2.314924
# 14  43.093506 -2.314843
# 15  43.093845 -2.314680
# 16  43.095784 -2.314705
# 17  43.094100 -2.313672
# 18  43.093385 -2.314011
# 19  43.093178 -2.313473
# 20  43.094105 -2.312938
# 21  43.094887 -2.312887
# 22  43.092924 -2.313075
# 23  43.092916 -2.313003
# 24  43.091745 -2.313578
# 25  43.091666 -2.313531
# 26  43.090623 -2.315702
# 27  43.089814 -2.316211
# 28  43.094393 -2.313842
# 29  43.092496 -2.313682
# 30  43.092436 -2.313660
# 31  43.089301 -2.318974

# %%
# Construct a folium map
urretxu = folium.Map(location=[43.090918759887956, -2.315669883437965], zoom_start=15)

# Create locations and markers
for row in trees.iterrows():
    row_values = row[1]
    location = [row_values["lat"], row_values["lng"]]
    popup = "<b>" + row_values["name"] + "</b>" + "\n"\
            + "<i>" + row_values["name_eu"] + "</i>" + "\n"\
            + row_values["name_es"]
    marker = folium.Marker(location=location, popup=popup, tooltip="Click me!")
    marker.add_to(urretxu)
    
# Display the map
urretxu
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4d34ad1be2409c6b7818e4b1e5f3be93 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4d34ad1be2409c6b7818e4b1e5f3be93&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4d34ad1be2409c6b7818e4b1e5f3be93 = L.map(
#                 &quot;map_4d34ad1be2409c6b7818e4b1e5f3be93&quot;,
#                 {
#                     center: [43.090918759887956, -2.315669883437965],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d50e3287246643970359bf9e0d9bedb8 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_4d34ad1be2409c6b7818e4b1e5f3be93);
#
#
#             var marker_2601e862eeff31fb6b55760e31a3ae62 = L.marker(
#                 [43.08671894121581, -2.321677951417283],
#                 {}
#             ).addTo(map_4d34ad1be2409c6b7818e4b1e5f3be93);
#
#
#         var popup_19d22a46535b7d9b606c0cbd3e51d48f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a8ae6078145cc0234e7d813aecdcab7d = $(`&lt;div id=&quot;html_a8ae6078145cc0234e7d813aecdcab7d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Liriodrendon tulipifera&lt;/b&gt; &lt;i&gt;Idio-bihotz arbola&lt;/i&gt; Tulipífero de Virginia&lt;/div&gt;`)[0];
#                 popup_19d22a46535b7d9b606c0cbd3e51d48f.setContent(html_a8ae6078145cc0234e7d813aecdcab7d);
#
#
#
#         marker_2601e862eeff31fb6b55760e31a3ae62.bindPopup(popup_19d22a46535b7d9b606c0cbd3e51d48f)
#         ;
#
#
#
#
#             marker_2601e862eeff31fb6b55760e31a3ae62.bindTooltip(
#                 `&lt;div&gt;
#                      Click me!
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_bf4db8b2ffc9b3dadb7552a9b61aefb3 = L.marker(
#                 [43.08678542751922, -2.321637174344012],
#                 {}
#             ).addTo(map_4d34ad1be2409c6b7818e4b1e5f3be93);
#
#
#         var popup_01e3e1e799c901f2708f9118a6a74f28 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c348bd4d6c6e9cce09d5eb5b79484b0b = $(`&lt;div id=&quot;html_c348bd4d6c6e9cce09d5eb5b79484b0b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Acer platanoides&lt;/b&gt; &lt;i&gt;Astigar zorrotza&lt;/i&gt; Arce real&lt;/div&gt;`)[0];
#                 popup_01e3e1e799c901f2708f9118a6a74f28.setContent(html_c348bd4d6c6e9cce09d5eb5b79484b0b);
#
#
#
#         marker_bf4db8b2ffc9b3dadb7552a9b61aefb3.bindPopup(popup_01e3e1e799c901f2708f9118a6a74f28)
#         ;
#
#
#
#
#             marker_bf4db8b2ffc9b3dadb7552a9b61aefb3.bindTooltip(
#                 `&lt;div&gt;
#                      Click me!
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_3ef696932ff9d9552890d9c7ddcb24cc = L.marker(
#                 [43.08829173852352, -2.321789851305967],
#                 {}
#             ).addTo(map_4d34ad1be2409c6b7818e4b1e5f3be93);
#
#
#         var popup_7412a4dc40c6fc27fe76a707d4f4ca21 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a4c01869021484ce374e1c48c527dac5 = $(`&lt;div id=&quot;html_a4c01869021484ce374e1c48c527dac5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Betula pubescens&lt;/b&gt; &lt;i&gt;Urki iletsua&lt;/i&gt; Abedul pubescente&lt;/div&gt;`)[0];
#                 popup_7412a4dc40c6fc27fe76a707d4f4ca21.setContent(html_a4c01869021484ce374e1c48c527dac5);
#
#
#
#         marker_3ef696932ff9d9552890d9c7ddcb24cc.bindPopup(popup_7412a4dc40c6fc27fe76a707d4f4ca21)
#         ;
#
#
#
#
#             marker_3ef696932ff9d9552890d9c7ddcb24cc.bindTooltip(
#                 `&lt;div&gt;
#                      Click me!
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_7ab81d79769a5f2b86fe0fd88265da77 = L.marker(
#                 [43.08846279770542, -2.321800282646452],
#                 {}
#             ).addTo(map_4d34ad1be2409c6b7818e4b1e5f3be93);
#
#
#         var popup_a63bbf54be0fda49859e458ed51e67b8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1792e65ff508adc813b7303d89b89d30 = $(`&lt;div id=&quot;html_1792e65ff508adc813b7303d89b89d30&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Prunus cerasifera&lt;/b&gt; &lt;i&gt;Aranondo japoniarra&lt;/i&gt; Ciruelo japonés&lt;/div&gt;`)[0];
#                 popup_a63bbf54be0fda49859e458ed51e67b8.setContent(html_1792e65ff508adc813b7303d89b89d30);
#
#
#
#         marker_7ab81d79769a5f2b86fe0fd88265da77.bindPopup(popup_a63bbf54be0fda49859e4
