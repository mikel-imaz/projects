# %% [markdown]
# (test)=
# # Test

# %%
import pandas as pd
import geopandas as gpd
import numpy as np
import matplotlib.pyplot as plt

# Import contextily
import contextily

# %%
zelai = gpd.read_file("ZELAI-ARIZTI PARKEA.geojson")
zelai
# Out:
#                                             geometry
# 0  POLYGON ((-2.32005 43.08835, -2.32073 43.08793...
# 1  POLYGON ((-2.31469 43.08989, -2.31566 43.08917...

# %%
geltoki = gpd.read_file("GELTOKIEN ENPARANTZA.geojson")
geltoki
# Out:
#                                             geometry
# 0  POLYGON ((-2.32005 43.08835, -2.32073 43.08793...

# %%
geltoki.plot()
plt.show()

# %%
# Plot with backgraound map
fig, ax = plt.subplots(figsize=(8, 8))
geltoki.plot(ax=ax)
zelai.plot(ax=ax)
contextily.add_basemap(ax,
                       # source=contextily.providers.OpenStreetMap.Mapnik,
                       # source=contextily.providers.CartoDB.PositronNoLabels,
                      )
ax.set_axis_off()
plt.show()
